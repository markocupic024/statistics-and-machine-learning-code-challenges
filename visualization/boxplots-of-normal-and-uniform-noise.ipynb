# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
n = 30
nd = np.random.randn(n)
ud =  np.random.rand(n)
data = np.array([nd, ud]).T
df = pd.DataFrame(data, columns=['Normal Distribution', 'Unifrom Distribution'])
sns.boxplot(data=df,orient='v')
# Out:
# <Axes: >
